# %% [markdown]
# # **Heart Disease Prediction**
#
# ## Data Collection
#
# This notebook focuses on downloading and collecting the dataset required for the project. The goal is to gather the necessary data, ensure its integrity, and prepare it for further processing and analysis.
#
# `Simón Correa Marín`

# %% [markdown]
# ### **1. Import Libraries**

# %%
# base libraries for data science
from pathlib import Path
import pandas as pd

# %% [markdown]
# ### **2. Collect Data**

# %%
url_data = "https://github.com/JoseRZapata/Data_analysis_notebooks/raw/refs/heads/main/data/datasets/corazon_data.csv"
heart_df = pd.read_csv(url_data, low_memory=False)  # no parsing of mixed types
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6848 entries, 0 to 6847
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rest_ecg     6403 non-null   object
#  1   ca           6482 non-null   object
#  2   thal         6557 non-null   object
#  3   max_hr       6456 non-null   object
#  4   exang        6499 non-null   object
#  5   old_peak     6496 non-null   object
#  6   chol         6649 non-null   object
#  7   rest_bp      6661 non-null   object
#  8   data_source  6845 non-null   object
#  9   chest_pain   6654 non-null   object
#  10  disease      6602 non-null   object
#  11  value        6845 non-null   float64
#  12  chest_pain   6654 non-null   object
#  13  csv          0 non-null      float64
#  14  sex          6700 non-null   object
#  15  thal         6557 non-null   object
#  16  fbs          6624 non-null   float64
#  17  slope        6495 non-null   object
#  18  rest_ecg     6403 non-null   object
#  19  disease      6602 non-null   object
#  20  age          6769 non-null   object
# dtypes: float64(3), object(18)
# memory usage: 1.1+ MB

# %%
heart_df.sample(10)
# Out:
#                            rest_ecg   ca        thal max_hr exang old_peak  \
# 5977                         normal  0.0      normal    179     0      0.0
# 4001                         normal  0.0      normal    187     0      3.5
# 6445                         normal  0.0  reversable    142     1      1.2
# 4239  left ventricular hypertrophy   0.0      normal    186     0      0.0
# 5959  left ventricular hypertrophy   0.0  reversable    156     1      0.0
# 4637  left ventricular hypertrophy   3.0  reversable    124     0      1.0
# 3990                         normal  1.0  reversable    156     0      0.1
# 6013                         normal  1.0  reversable     97     0      1.2
# 3147  left ventricular hypertrophy   0.0  reversable    128     0      2.6
# 4910                         normal  0.0  reversable    132     0      1.2
#
#      chol rest_bp data_source    chest_pain  ...     value   chest_pain  csv  \
# 5977  199      94     dataset    nonanginal  ...  105137.0    nonanginal NaN
# 4001  250     130     dataset    nonanginal  ...  105137.0    nonanginal NaN
# 6445  305     130     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 4239  222     122     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 5959  282     126     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 4637  289     165     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 3990  234     100     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 6013  263     130     dataset    nonanginal  ...  105137.0    nonanginal NaN
# 3147  243     150     dataset  asymptomatic  ...  105137.0  asymptomatic NaN
# 4910  264     110     dataset       typical  ...  105137.0       typical NaN
#
#          sex       thal   fbs  slope                      rest_ecg  disease   \
# 5977  Female      normal  0.0      1                         normal        0
# 4001    Male      normal  0.0      3                         normal        0
# 6445  Female  reversable  0.0      2                         normal        1
# 4239    Male      normal  0.0      1  left ventricular hypertrophy         0
# 5959    Male  reversable  0.0      1  left ventricular hypertrophy         1
# 4637    Male  reversable  1.0      2  left ventricular hypertrophy         1
# 3990    Male  reversable  0.0      1                         normal        1
# 6013  Female  reversable  0.0      2                         normal        1
# 3147    Male  reversable  0.0      2  left ventricular hypertrophy         1
# 4910    Male  reversable  0.0      2                         normal        1
#
#      age
# 5977  39
# 4001  37
# 6445  51
# 4239  48
# 5959  35
# 4637  57
# 3990  58
# 6013  62
# 3147  50
# 4910  45
#
# [10 rows x 21 columns]

# %% [markdown]
# ### **3. Data Information**

# %%
#Which columns are going to be used in the project?
heart_df.columns
# Out:
# Index(['rest_ecg', 'ca', 'thal', 'max_hr', 'exang', 'old_peak', 'chol',
#        'rest_bp', 'data_source', 'chest_pain', 'disease', 'value',
#        'chest_pain ', 'csv', 'sex', 'thal ', 'fbs', 'slope', 'rest_ecg ',
#        'disease ', 'age'],
#       dtype='object')

# %%
columns_to_use =

# %% [markdown]
# ### **4. Data Download**

# %%
heart_final_df = pd.read_csv(url_data, usecols=columns_to_use, low_memory=False)
heart_final_df.info()

# %%
#Locally
Path.cwd().resolve().parents[0]  # Define el directorio y el archivo
DATA_DIR = Path.cwd().resolve().parents[0] / "data/01_raw"

file_path = DATA_DIR / "titanic_raw.csv"

# Crea el directorio si no existe
DATA_DIR.mkdir(parents=True, exist_ok=True)
